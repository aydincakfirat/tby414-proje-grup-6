# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/firat/NewFolder1/1122.csv",sep=';')

# %%
df
# Out:
#           Date  Daily Cases  Total Cases  \
# 0   11 03 2020          1.0          1.0
# 1   12 03 2020          0.0          1.0
# 2   13 03 2020          4.0          5.0
# 3   14 03 2020          1.0          6.0
# 4   15 03 2020         12.0         18.0
# 5   16 03 2020         29.0         47.0
# 6   17 03 2020         51.0         98.0
# 7   18 03 2020         93.0        191.0
# 8   19 03 2020        168.0        359.0
# 9   20 03 2020        311.0        670.0
# 10  21 03 2020        277.0        947.0
# 11  22 03 2020        289.0       1236.0
# 12  23 03 2020        293.0       1529.0
# 13  24 03 2020        343.0       1872.0
# 14  25 03 2020        561.0       2433.0
# 15  26 03 2020       1196.0       3629.0
# 16  27 03 2020       2069.0       5698.0
# 17  28 03 2020       1704.0       7402.0
# 18  29 03 2020       1815.0       9217.0
# 19  30 03 2020       1610.0      10827.0
# 20  31 03 2020       2704.0      13531.0
# 21   1 04 2020       2148.0      15679.0
# ...

# %%
df.isnull().sum()
# Out:
# Date                                                  8
# Daily Cases                                           8
# Total Cases                                           8
# retail_and_recreation_percent_change_from_baseline    8
# grocery_and_pharmacy_percent_change_from_baseline     8
# parks_percent_change_from_baseline                    8
# transit_stations_percent_change_from_baseline         8
# workplaces_percent_change_from_baseline               8
# residential_percent_change_from_baseline              8
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)
df
# Out:
#           Date  Daily Cases  Total Cases  \
# 0   11 03 2020          1.0          1.0
# 1   12 03 2020          0.0          1.0
# 2   13 03 2020          4.0          5.0
# 3   14 03 2020          1.0          6.0
# 4   15 03 2020         12.0         18.0
# 5   16 03 2020         29.0         47.0
# 6   17 03 2020         51.0         98.0
# 7   18 03 2020         93.0        191.0
# 8   19 03 2020        168.0        359.0
# 9   20 03 2020        311.0        670.0
# 10  21 03 2020        277.0        947.0
# 11  22 03 2020        289.0       1236.0
# 12  23 03 2020        293.0       1529.0
# 13  24 03 2020        343.0       1872.0
# 14  25 03 2020        561.0       2433.0
# 15  26 03 2020       1196.0       3629.0
# 16  27 03 2020       2069.0       5698.0
# 17  28 03 2020       1704.0       7402.0
# 18  29 03 2020       1815.0       9217.0
# 19  30 03 2020       1610.0      10827.0
# 20  31 03 2020       2704.0      13531.0
# 21   1 04 2020       2148.0      15679.0
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Daily Cases', 'Total Cases',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
d=df["Date"]
dc=df["Daily Cases"]
tc=df["Total Cases"]
rr=df["retail_and_recreation_percent_change_from_baseline"]
gp=df["grocery_and_pharmacy_percent_change_from_baseline"]
p=df["parks_percent_change_from_baseline"]
ts=df["transit_stations_percent_change_from_baseline"]
w=df["workplaces_percent_change_from_baseline"]
r=df["residential_percent_change_from_baseline"]

# %%
plt.plot(dc,"red")#Daily Cases

# %%
plt.plot(rr)#retail_and_recreation_percent_change_from_baseline

# %%
plt.plot(gp,"green")#grocery_and_pharmacy_percent_change_from_baseline

# %%
plt.plot(p,"purple")#parks_percent_change_from_baseline

# %%
plt.plot(ts,"black")#transit_stations_percent_change_from_baseline

# %%
plt.plot(w)#workplaces_percent_change_from_baseline

# %%
plt.plot(r,"brown")#residential_percent_change_from_baseline

# %%
df.corr()
# Out:
#                                                     Daily Cases  Total Cases  \
# Daily Cases                                            1.000000    -0.023424
# Total Cases                                           -0.023424     1.000000
# retail_and_recreation_percent_change_from_baseline    -0.475832    -0.164278
# grocery_and_pharmacy_percent_change_from_baseline     -0.268761    -0.020123
# parks_percent_change_from_baseline                    -0.475045     0.095624
# transit_stations_percent_change_from_baseline         -0.515098    -0.174948
# workplaces_percent_change_from_baseline               -0.556075    -0.235559
# residential_percent_change_from_baseline               0.536112     0.120276
#
#                                                     retail_and_recreation_percent_change_from_baseline  \
# Daily Cases                                                                                 -0.475832
# ...
