# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/firat/NewFolder1/433.csv",sep=';')

# %%
df
# Out:
#          Date  DailyCases  Total Case  Total Cars on Traffic
# 0   4.01.2020        2148       15679             18696665.0
# 1   4.02.2020        2456       18135             17770314.0
# 2   4.03.2020        2786       20921             19651370.0
# 3   4.04.2020        3013       23934             13238808.0
# 4   4.05.2020        3135       27069              7448550.0
# 5   4.06.2020        3148       30217             16643633.0
# 6   4.07.2020        3892       34109             16891495.0
# 7   4.08.2020        4117       38226             17260393.0
# 8   4.09.2020        4056       42282             17494273.0
# 9   4.10.2020        4747       47029             19686418.0
# 10  4.11.2020        5138       52167              1391313.0
# 11  4.12.2021        4789       56956                    NaN
# 12  4.13.2020        4093       61049             19370799.0
# 13  4.14.2020        4062       65111             18972795.0
# ...

# %%
df.columns
# Out:
# Index(['Date', 'DailyCases', 'Total Case', 'Total Cars on Traffic'], dtype='object')

# %%
x = df["Date"]

# %%
y = df["DailyCases"]

# %%
y1 = df["Total Cars on Traffic"]

# %%
plt.plot(x,y,"red")
plt.plot(x,y1)
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
plt.plot(x,y,"red")

# %%
plt.scatter(y,y1)
